# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# setup some generic data
N = 37
x, y = np.mgrid[:N, :N]
Z = (np.cos(x*0.7) + np.sin(y*0.3))

fig, ax = plt.subplots(1)

# plot just the positive data and save the
# color "mappable" object returned by ax1.imshow
pos = ax.imshow(Z, cmap='Blues', interpolation='bilinear')

# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
fig.colorbar(pos, ax=ax)

plt.show()

# %%
print Z
# Out:
# [[ 1.          1.29552021  1.56464247 ...,  0.30012531  0.12030424
#    0.01906377]
#  [ 0.76484219  1.06036239  1.32948466 ...,  0.0649675  -0.11485357
#   -0.21609404]
#  [ 0.16996714  0.46548735  0.73460962 ..., -0.52990754 -0.70972862
#   -0.81096909]
#  ...,
#  [ 0.23581302  0.53133323  0.80045549 ..., -0.46406167 -0.64388274
#   -0.74512321]
#  [ 0.80640949  1.1019297   1.37105197 ...,  0.10653481 -0.07328627
#   -0.17452674]
#  [ 0.99773898  1.29325919  1.56238145 ...,  0.29786429  0.11804322
#    0.01680275]]

# %%
Z = [[0.89416945,1.809700495],[1.127062405,2.452254365]]

# %%
fig, ax = plt.subplots(1)

# plot just the positive data and save the
# color "mappable" object returned by ax1.imshow
pos = ax.imshow(Z, cmap='Blues', interpolation='bilinear')

# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
fig.colorbar(pos, ax=ax)

plt.show()

# %%
list1 = []

file = open("spacegroup127_C0_1.txt","r")

for line in file.readlines():
    list1.append(line.split()[0])
file.close()

two_d = np.zeros(shape=(11,11))

for i in range(11):
    for j in range(11):
        two_d[i,j] = list1[i*11 + j]
    
two_d
# Out:
# array([[ 0.92959577,  1.03494671,  1.14030292,  1.24540282,  1.34979187,
#          1.45132582,  1.54918429,  1.64280349,  1.72970493,  1.80884373,
#          1.87885283],
#        [ 0.98650998,  1.0982565 ,  1.21029795,  1.32206738,  1.43278862,
#          1.54034355,  1.6439234 ,  1.7431289 ,  1.83492042,  1.91871762,
#          1.99445209],
#        [ 1.04077352,  1.16071547,  1.28089126,  1.40096522,  1.51875852,
#          1.63359195,  1.74482439,  1.85001235,  1.94814946,  2.03790924,
#          2.11922437],
#        [ 1.09084948,  1.22034887,  1.35035564,  1.47893732,  1.6054195 ,
#          1.7285494 ,  1.84799899,  1.96100267,  2.06684321,  2.16531664,
#          2.25230584],
#        [ 1.13532819,  1.27527477,  1.41544599,  1.5539615 ,  1.69030975,
#          1.82384049,  1.95197964,  2.07408358,  2.18858182,  2.29574072,
#          2.39030142],
#        [ 1.17193079,  1.32378869,  1.47487343,  1.62459438,  1.77175262,
#          1.91606886,  2.05459806,  2.18660726,  2.31264103,  2.42760362,
#          2.53204289],
#        [ 1.20003757,  1.3637855 ,  1.52708394,  1.68886647,  1.84865349,
#          2.00366813,  2.15362922,  2.2972053 ,  2.43405258,  2.55974477,
#          2.67436376],
#        [ 1.21961035,  1.39399354,  1.5703981 ,  1.7457227 ,  1.91764187,
#          2.08515359,  2.2474974 ,  2.40474176,  2.5520322 ,  2.68987372,
#          2.81629519],
#        [ 1.23616683,  1.41540394,  1.60328811,  1.79222174,  1.97782097,
#          2.15918805,  2.33616495,  2.50512483,  2.66584474,  2.81655135,
#          2.95547503],
#        [ 1.2489541 ,  1.4338757 ,  1.62761107,  1.82803837,  2.02788804,
#          2.22362118,  2.41542541,  2.59859436,  2.77331663,  2.93774718,
#          3.09017258],
#        [ 1.2578482 ,  1.44957828,  1.64822662,  1.85401708,  2.06664329,
#          2.27936986,  2.48482071,  2.68304997,  2.87260574,  3.05177324,
#          3.2187444 ]])

# %%
fig, ax = plt.subplots(1)

# plot just the positive data and save the
# color "mappable" object returned by ax1.imshow
# Use of vmin and vmax to set the colourbar range
pos = ax.imshow(two_d, cmap='cool', interpolation='bilinear', vmin=0, vmax=4)

# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
fig.colorbar(pos, ax=ax)
ax.set_xlabel('$Q_B (-e)$',size=22)
ax.set_ylabel('$Q_A (-e)$',size=22)


labelsB = ['0.4', '0.5', '0.7', '0.9', '1.1', '1.3', '1.5']
labelsA = ['1.4', '1.5', '1.7', '1.9', '2.1', '2.3', '2.5']

ax.set_xticklabels(labelsA)
ax.set_yticklabels(labelsB)

plt.tight_layout()
plt.savefig('Spacegroup_127_C01_energies.png')
plt.show()

# %%
print two_d[1,10]
# Out:
# 1.994452085
