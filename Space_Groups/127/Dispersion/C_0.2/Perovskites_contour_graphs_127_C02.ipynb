# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# setup some generic data
N = 37
x, y = np.mgrid[:N, :N]
Z = (np.cos(x*0.7) + np.sin(y*0.3))

fig, ax = plt.subplots(1)

# plot just the positive data and save the
# color "mappable" object returned by ax1.imshow
pos = ax.imshow(Z, cmap='Blues', interpolation='bilinear')

# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
fig.colorbar(pos, ax=ax)

plt.show()

# %%
print Z
# Out:
# [[ 1.          1.29552021  1.56464247 ...,  0.30012531  0.12030424
#    0.01906377]
#  [ 0.76484219  1.06036239  1.32948466 ...,  0.0649675  -0.11485357
#   -0.21609404]
#  [ 0.16996714  0.46548735  0.73460962 ..., -0.52990754 -0.70972862
#   -0.81096909]
#  ...,
#  [ 0.23581302  0.53133323  0.80045549 ..., -0.46406167 -0.64388274
#   -0.74512321]
#  [ 0.80640949  1.1019297   1.37105197 ...,  0.10653481 -0.07328627
#   -0.17452674]
#  [ 0.99773898  1.29325919  1.56238145 ...,  0.29786429  0.11804322
#    0.01680275]]

# %%
Z = [[0.89416945,1.809700495],[1.127062405,2.452254365]]

# %%
fig, ax = plt.subplots(1)

# plot just the positive data and save the
# color "mappable" object returned by ax1.imshow
pos = ax.imshow(Z, cmap='Blues', interpolation='bilinear')

# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
fig.colorbar(pos, ax=ax)

plt.show()

# %%
list1 = []

file = open("spacegroup127_C0_2.txt","r")

for line in file.readlines():
    list1.append(line.split()[0])
file.close()

two_d = np.zeros(shape=(11,11))

for i in range(11):
    for j in range(11):
        two_d[i,j] = list1[i*11 + j]
    
two_d
# Out:
# array([[ 1.05364576,  1.1689948 ,  1.28527725,  1.40264106,  1.5179684 ,
#          1.63065771,  1.74116914,  1.84595659,  1.9440415 ,  2.03430558,
#          2.11803662],
#        [ 1.11472698,  1.23707999,  1.36045105,  1.48452371,  1.60622838,
#          1.72515102,  1.84149605,  1.9514339 ,  2.05456445,  2.15223083,
#          2.2375041 ],
#        [ 1.17431554,  1.30536344,  1.4378712 ,  1.56890001,  1.69823286,
#          1.82582581,  1.94800847,  2.06457393,  2.17390455,  2.27790749,
#          2.36813646],
#        [ 1.23124423,  1.37272399,  1.51367248,  1.65369593,  1.79131091,
#          1.9277423 ,  2.05815813,  2.18275271,  2.30261985,  2.41109415,
#          2.50805243],
#        [ 1.28301307,  1.43492004,  1.58596182,  1.73623642,  1.88562539,
#          2.0303976 ,  2.17016808,  2.30471334,  2.43247974,  2.54863623,
#          2.65454504],
#        [ 1.32836511,  1.49114853,  1.65384847,  1.81535667,  1.97583861,
#          2.13117366,  2.28108868,  2.42812058,  2.56360446,  2.69024834,
#          2.80552994],
#        [ 1.36480089,  1.54010171,  1.71518573,  1.89024764,  2.06119027,
#          2.22803177,  2.39298096,  2.54775096,  2.6948107 ,  2.83171519,
#          2.95749614],
#        [ 1.39363634,  1.5800308 ,  1.76953656,  1.95636803,  2.13991102,
#          2.31980682,  2.49709592,  2.66434741,  2.82380919,  2.97318734,
#          3.11044841],
#        [ 1.42005199,  1.61233693,  1.81273341,  2.01345045,  2.21123035,
#          2.40717393,  2.59565727,  2.77679489,  2.94955054,  3.1117443 ,
#          3.26155558],
#        [ 1.4428945 ,  1.64163482,  1.84760298,  2.06057578,  2.27551534,
#          2.4842748 ,  2.68706746,  2.88290364,  3.06953533,  3.24570125,
#          3.40907676],
#        [ 1.46462476,  1.66799155,  1.87880743,  2.09891536,  2.32700437,
#          2.55138766,  2.7696099 ,  2.98058141,  3.18250446,  3.37345632,
#          3.5517252 ]])

# %%
fig, ax = plt.subplots(1)

# plot just the positive data and save the
# color "mappable" object returned by ax1.imshow
# Use of vmin and vmax to set the colourbar range
pos = ax.imshow(two_d, cmap='cool', interpolation='bilinear', vmin=1.0, vmax=4)

# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
fig.colorbar(pos, ax=ax)
ax.set_xlabel('$Q_B (-e)$',size=22)
ax.set_ylabel('$Q_A (-e)$',size=22)


labelsB = ['0.4', '0.5', '0.7', '0.9', '1.1', '1.3', '1.5']
labelsA = ['1.4', '1.5', '1.7', '1.9', '2.1', '2.3', '2.5']

ax.set_xticklabels(labelsA)
ax.set_yticklabels(labelsB)

plt.tight_layout()
plt.savefig('Spacegroup_127_C02_energies.png')
plt.show()

# %%
print two_d[1,10]
# Out:
# 2.2375041
