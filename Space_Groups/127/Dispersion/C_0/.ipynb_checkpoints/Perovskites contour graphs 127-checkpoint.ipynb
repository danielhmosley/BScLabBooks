# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# setup some generic data
N = 37
x, y = np.mgrid[:N, :N]
Z = (np.cos(x*0.7) + np.sin(y*0.3))

fig, ax = plt.subplots(1)

# plot just the positive data and save the
# color "mappable" object returned by ax1.imshow
pos = ax.imshow(Z, cmap='Blues', interpolation='bilinear')

# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
fig.colorbar(pos, ax=ax)

plt.show()

# %%
print Z
# Out:
# [[ 1.          1.29552021  1.56464247 ...,  0.30012531  0.12030424
#    0.01906377]
#  [ 0.76484219  1.06036239  1.32948466 ...,  0.0649675  -0.11485357
#   -0.21609404]
#  [ 0.16996714  0.46548735  0.73460962 ..., -0.52990754 -0.70972862
#   -0.81096909]
#  ...,
#  [ 0.23581302  0.53133323  0.80045549 ..., -0.46406167 -0.64388274
#   -0.74512321]
#  [ 0.80640949  1.1019297   1.37105197 ...,  0.10653481 -0.07328627
#   -0.17452674]
#  [ 0.99773898  1.29325919  1.56238145 ...,  0.29786429  0.11804322
#    0.01680275]]

# %%
Z = [[0.89416945,1.809700495],[1.127062405,2.452254365]]

# %%
fig, ax = plt.subplots(1)

# plot just the positive data and save the
# color "mappable" object returned by ax1.imshow
pos = ax.imshow(Z, cmap='Blues', interpolation='bilinear')

# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
fig.colorbar(pos, ax=ax)

plt.show()

# %%
list1 = []

file = open("spacegroup127_C0.txt","r")

for line in file.readlines():
    list1.append(line.split()[0])
file.close()

two_d = np.zeros(shape=(11,11))

for i in range(11):
    for j in range(11):
        two_d[i,j] = list1[i*11 + j]
    
two_d
# Out:
# array([[ 0.89416945,  0.99613659,  1.09826311,  1.20007549,  1.30094582,
#          1.39907924,  1.49360666,  1.58322554,  1.66710507,  1.74299388,
#          1.80970049],
#        [ 0.94941297,  1.05798127,  1.16693348,  1.27526001,  1.38243824,
#          1.48657866,  1.58676445,  1.68232367,  1.77089028,  1.85129755,
#          1.92236863],
#        [ 1.00205122,  1.11881403,  1.23584824,  1.35229428,  1.46667698,
#          1.57807726,  1.68522131,  1.78743852,  1.88224065,  1.96881763,
#          2.04649965],
#        [ 1.05033924,  1.17657773,  1.30277067,  1.42827767,  1.55136165,
#          1.67105978,  1.78685221,  1.89643702,  1.9988955 ,  2.09275931,
#          2.17737571],
#        [ 1.09270939,  1.22935833,  1.3661181 ,  1.50115677,  1.63403619,
#          1.76337992,  1.88859205,  2.00719312,  2.11833119,  2.22167359,
#          2.31317221],
#        [ 1.1270624 ,  1.27542336,  1.42308849,  1.56933631,  1.71306779,
#          1.85356257,  1.98860291,  2.11722145,  2.23931806,  2.3510671 ,
#          2.45225436],
#        [ 1.15214806,  1.31282484,  1.47265598,  1.6309186 ,  1.78693859,
#          1.93846541,  2.08491394,  2.22496364,  2.35793422,  2.48052428,
#          2.59197727],
#        [ 1.1693445 ,  1.34021367,  1.51309702,  1.68417438,  1.85299313,
#          2.0172407 ,  2.17594792,  2.32905859,  2.4730113 ,  2.60738101,
#          2.73050691],
#        [ 1.18301459,  1.35901421,  1.54272238,  1.72815516,  1.91006509,
#          2.08780677,  2.25982345,  2.42629915,  2.58334373,  2.73058327,
#          2.86620148],
#        [ 1.19280836,  1.37419402,  1.56393758,  1.76054365,  1.95679868,
#          2.14887544,  2.33648535,  2.51600751,  2.68710704,  2.84804615,
#          2.99714854],
#        [ 1.19842075,  1.38634381,  1.58121808,  1.78318021,  1.99195862,
#          2.20038447,  2.40218306,  2.59659268,  2.78254492,  2.95811014,
#          3.12170814]])

# %%
fig, ax = plt.subplots(1)

# plot just the positive data and save the
# color "mappable" object returned by ax1.imshow
# use vmin and vmax to select the range of the colour bar
pos = ax.imshow(two_d, cmap='cool', interpolation='bilinear', vmin=0, vmax=4)

# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
fig.colorbar(pos, ax=ax)
ax.set_xlabel('$Q_B (-e)$',size=22)
ax.set_ylabel('$Q_A (-e)$',size=22)


labelsB = ['0.4', '0.5', '0.7', '0.9', '1.1', '1.3', '1.5']
labelsA = ['1.4', '1.5', '1.7', '1.9', '2.1', '2.3', '2.5']

ax.set_xticklabels(labelsA)
ax.set_yticklabels(labelsB)

plt.tight_layout()
plt.savefig('Spacegroup_167_energies.png')
plt.show()

# %%
print two_d[1,10]
# Out:
# 1.922368635
