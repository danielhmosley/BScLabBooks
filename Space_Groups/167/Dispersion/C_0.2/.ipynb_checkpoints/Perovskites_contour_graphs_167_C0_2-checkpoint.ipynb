# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# setup some generic data
N = 37
x, y = np.mgrid[:N, :N]
Z = (np.cos(x*0.7) + np.sin(y*0.3))

fig, ax = plt.subplots(1)

# plot just the positive data and save the
# color "mappable" object returned by ax1.imshow
pos = ax.imshow(Z, cmap='Blues', interpolation='bilinear')

# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
fig.colorbar(pos, ax=ax)

plt.show()

# %%
print Z
# Out:
# [[ 1.          1.29552021  1.56464247 ...,  0.30012531  0.12030424
#    0.01906377]
#  [ 0.76484219  1.06036239  1.32948466 ...,  0.0649675  -0.11485357
#   -0.21609404]
#  [ 0.16996714  0.46548735  0.73460962 ..., -0.52990754 -0.70972862
#   -0.81096909]
#  ...,
#  [ 0.23581302  0.53133323  0.80045549 ..., -0.46406167 -0.64388274
#   -0.74512321]
#  [ 0.80640949  1.1019297   1.37105197 ...,  0.10653481 -0.07328627
#   -0.17452674]
#  [ 0.99773898  1.29325919  1.56238145 ...,  0.29786429  0.11804322
#    0.01680275]]

# %%
Z = [[0.89416945,1.809700495],[1.127062405,2.452254365]]

# %%
fig, ax = plt.subplots(1)

# plot just the positive data and save the
# color "mappable" object returned by ax1.imshow
pos = ax.imshow(Z, cmap='Blues', interpolation='bilinear')

# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
fig.colorbar(pos, ax=ax)

plt.show()

# %%
list1 = []

file = open("spacegroup167.txt","r")

for line in file.readlines():
    list1.append(line.split()[0])
file.close()

two_d = np.zeros(shape=(11,11))

for i in range(11):
    for j in range(11):
        two_d[i,j] = list1[i*11 + j]
    
two_d
# Out:
# array([[  3.06124264,   3.58122744,   2.75156092,   3.15069102,
#           3.57798543,   2.81399771,   5.88293966,   6.55464109,
#           5.57296248,   6.14529289,   6.7476911 ],
#        [  1.98782727,   2.3433029 ,   2.72587812,   3.13639759,
#           3.57553103,   5.70524474,   6.78699446,   7.59748274,
#           8.39349216,   9.28034112,  10.21429425],
#        [  1.90378095,   2.26946095,   2.66280642,   3.08452996,
#           5.08248642,   5.13989451,   6.61966152,   7.42712088,
#           8.28348801,   9.18850951,  10.14335787],
#        [  2.54712058,   2.15824492,   2.56212433,   2.9947329 ,
#           4.94877221,   5.65313239,   6.41650619,   7.22883202,
#           8.09146777,   9.00479626,   9.97105076],
#        [  1.62272124,   2.0086973 ,   2.42341936,   4.0284976 ,
#           4.69597032,   5.41127267,   6.17569304,   6.98914224,
#           7.85251004,   8.76873866,   5.11458372],
#        [  1.42317595,   1.81962912,   2.24429241,   3.74684467,
#           4.41520737,   5.13182771,   5.89665518,   6.71058474,
#           7.57650452,   8.49301117,   6.71983443],
#        [  1.18198707,   1.58864436,   2.02385   ,   3.42637351,
#           4.09584626,   4.812683  ,   5.57778312,   6.39308227,
#           5.26677398,   5.91452203,   6.59402112],
#        [  0.89769031,   1.31434801,   1.71882686,   3.06579158,
#           3.73580301,   4.45272503,   5.21899685,   4.44406476,
#           5.07323327,   5.7338665 ,   6.42603396],
#        [  0.56804597,   0.99509106,   1.2633029 ,   2.6645202 ,
#           3.33395508,   4.05187284,   3.58308625,   4.19430103,
#           4.83590944,   5.50932786,   6.21478362],
#        [  0.1915672 ,   0.62739623,   1.59727986,   2.21995873,
#           2.89023237,   3.60857903,   3.27577423,   3.89856208,
#           4.55297922,   5.23955779,   5.95823208],
#        [ -0.23330927,   0.21542243,   0.6937519 ,   1.73254654,
#           2.40309818,   2.31639215,   2.91997985,   3.55543788,
#           4.22290124,   4.92265194,   5.65480962]])

# %%
fig, ax = plt.subplots(1)

# plot just the positive data and save the
# color "mappable" object returned by ax1.imshow
pos = ax.imshow(two_d, cmap='cool', interpolation='bilinear')

# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
fig.colorbar(pos, ax=ax)
ax.set_xlabel('$Q_B (-e)$',size=22)
ax.set_ylabel('$Q_A (-e)$',size=22)


labelsB = ['0.4', '0.5', '0.7', '0.9', '1.1', '1.3', '1.5']
labelsA = ['1.4', '1.5', '1.7', '1.9', '2.1', '2.3', '2.5']

ax.set_xticklabels(labelsA)
ax.set_yticklabels(labelsB)

plt.tight_layout()
plt.savefig('Spacegroup_167_energies.png')
plt.show()

# %%
print two_d[1,10]
# Out:
# 10.21429425
