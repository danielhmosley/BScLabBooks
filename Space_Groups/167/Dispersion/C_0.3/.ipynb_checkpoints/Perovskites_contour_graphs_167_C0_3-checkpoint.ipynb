# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# setup some generic data
N = 37
x, y = np.mgrid[:N, :N]
Z = (np.cos(x*0.7) + np.sin(y*0.3))

fig, ax = plt.subplots(1)

# plot just the positive data and save the
# color "mappable" object returned by ax1.imshow
pos = ax.imshow(Z, cmap='Blues', interpolation='bilinear')

# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
fig.colorbar(pos, ax=ax)

plt.show()

# %%
print Z
# Out:
# [[ 1.          1.29552021  1.56464247 ...,  0.30012531  0.12030424
#    0.01906377]
#  [ 0.76484219  1.06036239  1.32948466 ...,  0.0649675  -0.11485357
#   -0.21609404]
#  [ 0.16996714  0.46548735  0.73460962 ..., -0.52990754 -0.70972862
#   -0.81096909]
#  ...,
#  [ 0.23581302  0.53133323  0.80045549 ..., -0.46406167 -0.64388274
#   -0.74512321]
#  [ 0.80640949  1.1019297   1.37105197 ...,  0.10653481 -0.07328627
#   -0.17452674]
#  [ 0.99773898  1.29325919  1.56238145 ...,  0.29786429  0.11804322
#    0.01680275]]

# %%
Z = [[0.89416945,1.809700495],[1.127062405,2.452254365]]

# %%
fig, ax = plt.subplots(1)

# plot just the positive data and save the
# color "mappable" object returned by ax1.imshow
pos = ax.imshow(Z, cmap='Blues', interpolation='bilinear')

# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
fig.colorbar(pos, ax=ax)

plt.show()

# %%
list1 = []

file = open("spacegroup167_C0_3.txt","r")

for line in file.readlines():
    list1.append(line.split()[0])
file.close()

two_d = np.zeros(shape=(11,11))

for i in range(11):
    for j in range(11):
        two_d[i,j] = list1[i*11 + j]
    
two_d
# Out:
# array([[ 2.13389996,  2.49622655,  2.88853916,  3.30717841,  3.75648966,
#          4.23791493,  4.74904361,  5.29123282,  5.86527477,  6.47616438,
#          8.46444885],
#        [ 2.10989638,  2.48552171,  2.89228416,  3.32656171,  3.79207078,
#          4.28982144,  4.81653064,  5.37535879,  7.35629467,  8.09488867,
#          8.87061393],
#        [ 2.03962492,  2.429663  ,  2.84865083,  3.29706806,  3.77895448,
#          4.28974042,  4.83216926,  6.86904277,  7.61373319,  8.38935759,
#          9.20400193],
#        [ 1.92699526,  2.32866784,  2.76025138,  3.22170756,  3.71683221,
#          4.24167661,  4.79804821,  5.39207086,  6.01430125,  6.66903513,
#          7.35844913],
#        [ 1.77056022,  2.18380162,  2.62755218,  3.10339382,  3.6092407 ,
#          4.14763906,  4.72147351,  5.32653576,  5.96257226,  6.63225537,
#          7.33697328],
#        [ 1.56984594,  1.99422955,  2.44934155,  2.93792589,  3.45703093,
#          4.00854318,  4.59680771,  6.89850941,  5.86456441,  6.54959777,
#          7.26910579],
#        [ 1.32345805,  1.75903653,  2.2279729 ,  2.72716634,  3.25885282,
#          3.82656046,  4.42377178,  5.05535297,  5.72065754,  6.41911752,
#          7.15365308],
#        [ 1.02993578,  1.4795911 ,  1.95818325,  2.46971096,  3.01528522,
#          3.59394102,  4.20512171,  4.84923882,  5.52772741,  6.24207793,
#          6.99087639],
#        [ 0.69085405,  1.50514263,  1.63912898,  2.16258872,  2.72336286,
#          3.31259662,  3.93701858,  4.59508757,  5.28788246,  6.01583031,
#          6.77959502],
#        [ 0.29886716,  0.76800455,  1.27084258,  1.80975822,  2.96771152,
#          2.98198004,  3.61936641,  4.29110376,  4.99774265,  5.74057731,
#          6.52196633],
#        [-0.14610581,  0.33508013,  0.85304945,  1.40126682,  1.98343826,
#          2.59971941,  3.25014407,  3.93525626,  4.65691976,  5.41442895,
#          6.21040779]])

# %%
fig, ax = plt.subplots(1)

# plot just the positive data and save the
# color "mappable" object returned by ax1.imshow
pos = ax.imshow(two_d, cmap='cool', interpolation='bilinear')

# add the colorbar using the figure's method,
# telling which mappable we're talking about and
# which axes object it should be near
fig.colorbar(pos, ax=ax)
ax.set_xlabel('$Q_B (-e)$',size=22)
ax.set_ylabel('$Q_A (-e)$',size=22)


labelsB = ['0.4', '0.5', '0.7', '0.9', '1.1', '1.3', '1.5']
labelsA = ['1.4', '1.5', '1.7', '1.9', '2.1', '2.3', '2.5']

ax.set_xticklabels(labelsA)
ax.set_yticklabels(labelsB)

plt.tight_layout()
plt.savefig('Spacegroup_167_energies.png')
plt.show()

# %%
print two_d[1,10]
# Out:
# 8.870613925
